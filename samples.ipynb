# %%
import pandas as pd
import numpy as np
import tensorflow as tf

# %%
# Loading the data
X_dataset = pd.read_excel('110_Samples_Dados_RNN_tr_10volunt_all_0_4_ga_ana_ma_mar_bia_emb.xlsx', header=None)
Y_dataset = pd.read_excel('Y.xls')

# %%
X_dataset
# Out:
#         0.9393283786470006  0.5967872911087334  1.089826274766493  \
# 0                 0.939328            0.612619           1.064275
# 1                 0.902404            0.612619           1.064275
# 2                 0.939328            0.596787           1.064275
# 3                 0.957791            0.612619           1.064275
# 4                 0.939328            0.628451           1.089826
# ...                    ...                 ...                ...
# 428994           -0.242263           -0.685605           0.067789
# 428995           -0.149952           -0.685605           0.067789
# 428996           -0.113027           -0.669773           0.067789
# 428997           -0.113027           -0.685605           0.067789
# 428998           -0.113027           -0.685605           0.067789
#
#         1.15030560061266  0.994553938039888  1.953934076529348  \
# 0               1.150306           1.009323           1.970652
# ...
